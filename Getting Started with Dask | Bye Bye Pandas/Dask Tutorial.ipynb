# %%
import dask.dataframe as dd

# %%
import pandas as pd

# %%
# %time df_p = pd.read_csv("spotify_dataset/data.csv")
# Out:
# CPU times: user 620 ms, sys: 83.9 ms, total: 704 ms
# Wall time: 896 ms

# %%
# %time df_d = dd.read_csv("spotify_dataset/data.csv")
# Out:
# CPU times: user 14.6 ms, sys: 4.11 ms, total: 18.7 ms
# Wall time: 33.9 ms

# %%
# Out:
# 37.64705882352941

# %%
df_d.rcompute()
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# ...

# %%
df_d.popularity.value_counts().compute()
# Out:
# 0      40905
# 1       3846
# 33      2819
# 34      2790
# 36      2784
#        ...
# 94         5
# 93         2
# 96         2
# 95         2
# 100        1
# Name: popularity, Length: 98, dtype: int64
